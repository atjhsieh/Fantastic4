# %%
#import dependencies 
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

df = pd.read_csv('merged.csv')
df
# Out:
#      suicide_country  suicide_year     sex          age  suicides_no  \
# 0            Albania          2007    male    75+ years            8
# 1            Albania          2007    male  35-54 years           29
# 2            Albania          2007    male  55-74 years           14
# 3            Albania          2007  female    75+ years            3
# 4            Albania          2007    male  25-34 years            9
# 5            Albania          2007  female  15-24 years           13
# 6            Albania          2007    male  15-24 years           13
# 7            Albania          2007  female  25-34 years            8
# 8            Albania          2007  female  55-74 years            9
# 9            Albania          2007  female  35-54 years           14
# 10           Albania          2007    male   5-14 years            4
# 11           Albania          2007  female   5-14 years            0
# 12           Albania          2009  female  15-24 years            0
# 13           Albania          2009  female  25-34 years            0
# 14           Albania          2009  female  35-54 years            0
# 15           Albania          2009  female   5-14 years            0
# 16           Albania          2009  female  55-74 years            0
# 17           Albania          2009  female    75+ years            0
# 18           Albania          2009    male  15-24 years            0
# 19           Albania          2009    male  25-34 years            0
# 20           Albania          2009    male  35-54 years            0
# 21           Albania          2009    male   5-14 years            0
# 22           Albania          2009    male  55-74 years            0
# 23           Albania          2009    male    75+ years            0
# 24           Albania          2010    male  55-74 years           20
# 25           Albania          2010    male  35-54 years           20
# 26           Albania          2010    male  25-34 years            9
# 27           Albania          2010    male    75+ years            2
# 28           Albania          2010    male  15-24 years           10
# 29           Albania          2010  female  25-34 years            6
# ...              ...           ...     ...          ...          ...
# 7262          Russia          2013  female  35-54 years         1454
# 7263          Russia          2013  female  25-34 years          803
# 7264          Russia          2013  female  55-74 years         1154
# 7265          Russia          2013  female  15-24 years          511
# 7266          Russia          2013    male   5-14 years          111
# 7267          Russia          2013  female   5-14 years           54
# 7268          Russia          2014    male    75+ years         1597
# 7269          Russia          2014    male  25-34 years         5276
# 7270          Russia          2014    male  35-54 years         8105
# 7271          Russia          2014    male  55-74 years         4501
# 7272          Russia          2014    male  15-24 years         2311
# 7273          Russia          2014  female    75+ years         1019
# 7274          Russia          2014  female  55-74 years         1105
# 7275          Russia          2014  female  35-54 years         1297
# 7276          Russia          2014  female  25-34 years          723
# 7277          Russia          2014  female  15-24 years          467
# 7278          Russia          2014    male   5-14 years           96
# 7279          Russia          2014  female   5-14 years           44
# 7280          Russia          2015    male    75+ years         1519
# 7281          Russia          2015    male  35-54 years         7898
# 7282          Russia          2015    male  25-34 years         4994
# 7283          Russia          2015    male  55-74 years         4443
# 7284          Russia          2015    male  15-24 years         1928
# 7285          Russia          2015  female    75+ years          953
# 7286          Russia          2015  female  35-54 years         1391
# 7287          Russia          2015  female  25-34 years          730
# 7288          Russia          2015  female  55-74 years         1062
# 7289          Russia          2015  female  15-24 years          378
# 7290          Russia          2015    male   5-14 years           79
# 7291          Russia          2015  female   5-14 years           57
#
#       population  suicides/100k pop            country-year  HDI for year  \
# 0          42366              18.88             Albania2007           NaN
# 1         378626               7.66             Albania2007           NaN
# 2         224160               6.25             Albania2007           NaN
# 3          57404               5.23             Albania2007           NaN
# 4         172494               5.22             Albania2007           NaN
# 5         281080               4.63             Albania2007           NaN
# 6         288349               4.51             Albania2007           NaN
# 7         183629               4.36             Albania2007           NaN
# 8         221120               4.07             Albania2007           NaN
# 9         391811               3.57             Albania2007           NaN
# 10        272497               1.47             Albania2007           NaN
# 11        256808               0.00             Albania2007           NaN
# 12        270003               0.00             Albania2009           NaN
# 13        182712               0.00             Albania2009           NaN
# 14        394286               0.00             Albania2009           NaN
# 15        236174               0.00             Albania2009           NaN
# 16        233302               0.00             Albania2009           NaN
# 17         61582               0.00             Albania2009           NaN
# 18        283448               0.00             Albania2009           NaN
# 19        174955               0.00             Albania2009           NaN
# 20        374365               0.00             Albania2009           NaN
# 21        253007               0.00             Albania2009           NaN
# 22        234570               0.00             Albania2009           NaN
# 23         47331               0.00             Albania2009           NaN
# 24        241852               8.27             Albania2010         0.722
# 25        371611               5.38             Albania2010         0.722
# 26        179720               5.01             Albania2010         0.722
# 27         50767               3.94             Albania2010         0.722
# 28        279508               3.58             Albania2010         0.722
# 29        183579               3.27             Albania2010         0.722
# ...          ...                ...                     ...           ...
# 7262    21385188               6.80  Russian Federation2013           NaN
# 7263    11984461               6.70  Russian Federation2013           NaN
# 7264    17517861               6.59  Russian Federation2013           NaN
# 7265     8554683               5.97  Russian Federation2013           NaN
# 7266     7327888               1.51  Russian Federation2013           NaN
# 7267     6979537               0.77  Russian Federation2013           NaN
# 7268     2349484              67.97  Russian Federation2014           NaN
# 7269    12057910              43.76  Russian Federation2014           NaN
# 7270    19484117              41.60  Russian Federation2014           NaN
# 7271    11808589              38.12  Russian Federation2014           NaN
# 7272     8908926              25.94  Russian Federation2014           NaN
# 7273     6355318              16.03  Russian Federation2014           NaN
# 7274    17517861               6.31  Russian Federation2014           NaN
# 7275    21385188               6.06  Russian Federation2014           NaN
# 7276    11984461               6.03  Russian Federation2014           NaN
# 7277     8554683               5.46  Russian Federation2014           NaN
# 7278     7327888               1.31  Russian Federation2014           NaN
# 7279     6979537               0.63  Russian Federation2014           NaN
# 7280     2608590              58.23  Russian Federation2015           NaN
# 7281    19598084              40.30  Russian Federation2015           NaN
# 7282    12407057              40.25  Russian Federation2015           NaN
# 7283    12564884              35.36  Russian Federation2015           NaN
# 7284     7995706              24.11  Russian Federation2015           NaN
# 7285     6957819              13.70  Russian Federation2015           NaN
# 7286    21387236               6.50  Russian Federation2015           NaN
# 7287    12264840               5.95  Russian Federation2015           NaN
# 7288    18280577               5.81  Russian Federation2015           NaN
# 7289     7653174               4.94  Russian Federation2015           NaN
# 7290     7836667               1.01  Russian Federation2015           NaN
# 7291     7464309               0.76  Russian Federation2015           NaN
#
#        gdp_for_year ($)       ...         Positive affect Negative affect  \
# 0           10701011897       ...                0.552678        0.246335
# 1           10701011897       ...                0.552678        0.246335
# 2           10701011897       ...                0.552678        0.246335
# 3           10701011897       ...                0.552678        0.246335
# 4           10701011897       ...                0.552678        0.246335
# 5           10701011897       ...                0.552678        0.246335
# 6           10701011897       ...                0.552678        0.246335
# 7           10701011897       ...                0.552678        0.246335
# 28                                 NaN                             0.30325
# 29                                 NaN                             0.30325
# ...                                ...                                 ...
# 7262                             0.409                             0.39925
# 7263                             0.409                             0.39925
# 7264                             0.409                             0.39925
# 7265                             0.409                             0.39925
# 7266                             0.409                             0.39925
# 7267                             0.409                             0.39925
# 7268                             0.399                             0.39925
# 7269                             0.399                             0.39925
# 7270                             0.399                             0.39925
# 7271                             0.399                             0.39925
# 7272                             0.399                             0.39925
# 7273                             0.399                             0.39925
# 7274                             0.399                             0.39925
# 7275                             0.399                             0.39925
# 7276                             0.399                             0.39925
# 7277                             0.399                             0.39925
# 7278                             0.399                             0.39925
# 7279                             0.399                             0.39925
# 7280                             0.377                             0.39925
# 7281                             0.377                             0.39925
# 7282                             0.377                             0.39925
# 7283                             0.377                             0.39925
# 7284                             0.377                             0.39925
# 7285                             0.377                             0.39925
# 7286                             0.377                             0.39925
# 7287                             0.377                             0.39925
# 7288                             0.377                             0.39925
# 7289                             0.377                             0.39925
# 7290                             0.377                             0.39925
# 7291                             0.377                             0.39925
#
#       average 2000-15
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12           0.617361
# 13           0.617361
# 14           0.617361
# 15           0.617361
# 16           0.617361
# 17           0.617361
# 18           0.617361
# 19           0.617361
# 20           0.617361
# 21           0.617361
# 22           0.617361
# 23           0.617361
# 24           0.543528
# 25           0.543528
# 26           0.543528
# 27           0.543528
# 28           0.543528
# 29           0.543528
# ...               ...
# 7262         0.342804
# 7263         0.342804
# 7264         0.342804
# 7265         0.342804
# 7266         0.342804
# 7267         0.342804
# 7268         0.343749
# 7269         0.343749
# 7270         0.343749
# 7271         0.343749
# 7272         0.343749
# 7273         0.343749
# 7274         0.343749
# 7275         0.343749
# 7276         0.343749
# 7277         0.343749
# 7278         0.343749
# 7279         0.343749
# 7280         0.330878
# 7281         0.330878
# 7282         0.330878
# 7283         0.330878
# 7284         0.330878
# 7285         0.330878
# 7286         0.330878
# 7287         0.330878
# 7288         0.330878
# 7289         0.330878
# 7290         0.330878
# 7291         0.330878
#
# [7292 rows x 31 columns]

# %%
#get column names
df.columns
# Out:
# Index(['suicide_country', 'suicide_year', 'sex', 'age', 'suicides_no',
#        'population', 'suicides/100k pop', 'country-year', 'HDI for year',
#        'gdp_for_year ($)', 'gdp_per_capita ($)', 'Generation',
#        'WHR2018Chapter2OnlineData_country', 'WHR2018Chapter2OnlineData_year',
#        'Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government',
#        'Democratic Quality', 'Delivery Quality',
#        'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate).1', 'average 2000-15'],
#       dtype='object')

# %%
#drop columns with no data - for some reason I'm getting an error now that things are cleaned out. 
df.drop(columns=['country-year', 'HDI for year', 'GINI index (World Bank estimate)', 'average 2000-15'], inplace=True)

# %%
#drop all NaNs
clean_df = df.dropna()
clean_df.head()
# Out:
#   suicide_country  suicide_year     sex          age  suicides_no  population  \
# 0         Albania          2007    male    75+ years            8       42366
# 1         Albania          2007    male  35-54 years           29      378626
# 2         Albania          2007    male  55-74 years           14      224160
# 3         Albania          2007  female    75+ years            3       57404
# 4         Albania          2007    male  25-34 years            9      172494
#
#    suicides/100k pop gdp_for_year ($)  gdp_per_capita ($)    Generation  \
# 0              18.88      10701011897                3863        Silent
# 1               7.66      10701011897                3863       Boomers
# 2               6.25      10701011897                3863        Silent
# 3               5.23      10701011897                3863        Silent
# 4               5.22      10701011897                3863  Generation X
#
#                   ...                 Generosity  Perceptions of corruption  \
# 0                 ...                  -0.016183                     0.8747
# 1                 ...                  -0.016183                     0.8747
# 2                 ...                  -0.016183                     0.8747
# 3                 ...                  -0.016183                     0.8747
# 4                 ...                  -0.016183                     0.8747
#
#    Positive affect  Negative affect  Confidence in national government  \
# 0         0.552678         0.246335                           0.300681
# 1         0.552678         0.246335                           0.300681
# 2         0.552678         0.246335                           0.300681
# 3         0.552678         0.246335                           0.300681
# 4         0.552678         0.246335                           0.300681
#
#    Democratic Quality  Delivery Quality  \
# 0           -0.045108         -0.420024
# 1           -0.045108         -0.420024
# 2           -0.045108         -0.420024
# 3           -0.045108         -0.420024
# 4           -0.045108         -0.420024
#
#    Standard deviation of ladder by country-year  \
# 0                                      1.764947
# 1                                      1.764947
# 2                                      1.764947
# 3                                      1.764947
# 4                                      1.764947
#
#    Standard deviation/Mean of ladder by country-year  \
# 0                                           0.380848
# 1                                           0.380848
# 2                                           0.380848
# 3                                           0.380848
# 4                                           0.380848
#
#    GINI index (World Bank estimate).1
# 0                             0.30325
# 1                             0.30325
# 2                             0.30325
# 3                             0.30325
# 4                             0.30325
#
# [5 rows x 27 columns]

# %%
#drop columns with no data - for some reason I'm getting an error now that things are cleaned out. 
df.drop(columns=['Positive affect',
       'Negative affect', 'Confidence in national government',
       'Democratic Quality', 'Delivery Quality',
       'Standard deviation of ladder by country-year',
       'Standard deviation/Mean of ladder by country-year',
       'GINI index (World Bank estimate).1'], inplace=True)

clean_df.head()
# Out:
#   suicide_country  suicide_year     sex          age  suicides_no  population  \
# 0         Albania          2007    male    75+ years            8       42366
# 1         Albania          2007    male  35-54 years           29      378626
# 2         Albania          2007    male  55-74 years           14      224160
# 3         Albania          2007  female    75+ years            3       57404
# 4         Albania          2007    male  25-34 years            9      172494
#
#    suicides/100k pop gdp_for_year ($)  gdp_per_capita ($)    Generation  \
# 0              18.88      10701011897                3863        Silent
# 1               7.66      10701011897                3863       Boomers
# 2               6.25      10701011897                3863        Silent
# 3               5.23      10701011897                3863        Silent
# 4               5.22      10701011897                3863  Generation X
#
#                   ...                 Generosity  Perceptions of corruption  \
# 0                 ...                  -0.016183                     0.8747
# 1                 ...                  -0.016183                     0.8747
# 2                 ...                  -0.016183                     0.8747
# 3                 ...                  -0.016183                     0.8747
# 4                 ...                  -0.016183                     0.8747
#
#    Positive affect  Negative affect  Confidence in national government  \
# 0         0.552678         0.246335                           0.300681
# 1         0.552678         0.246335                           0.300681
# 2         0.552678         0.246335                           0.300681
# 3         0.552678         0.246335                           0.300681
# 4         0.552678         0.246335                           0.300681
#
#    Democratic Quality  Delivery Quality  \
# 0           -0.045108         -0.420024
# 1           -0.045108         -0.420024
# 2           -0.045108         -0.420024
# 3           -0.045108         -0.420024
# 4           -0.045108         -0.420024
#
#    Standard deviation of ladder by country-year  \
# 0                                      1.764947
# 1                                      1.764947
# 2                                      1.764947
# 3                                      1.764947
# 4                                      1.764947
#
#    Standard deviation/Mean of ladder by country-year  \
# 0                                           0.380848
# 1                                           0.380848
# 2                                           0.380848
# 3                                           0.380848
# 4                                           0.380848
#
#    GINI index (World Bank estimate).1
# 0                             0.30325
# 1                             0.30325
# 2                             0.30325
# 3                             0.30325
# 4                             0.30325
#
# [5 rows x 27 columns]

# %%
#new df with all the NaNs removed - but it looks like we may have lost some countries? 
clean_df.describe()

# %%
# #test to see if I'm getting nay more NaNs - comes up false
# np.isnan(clean_df.any())

# %%
# Function to count and check values - 
#borrowed from https://www.kaggle.com/marcellosusanto/simple-analysis-on-suicide-rates-overview/data

def check_missing_values(df) :
    n = len(df)
    var = list(df.columns)
    missing_var = []
    missing_count = []
    print('Variable with missing values :')
    
    for i in var :
        count = np.sum(df[i].isna())
        count_percentage = round(count*100/n, 2)
        if count > 0 :
            print(i,':',count,'//',count_percentage,'%')
            missing_var.append(i)
            missing_count.append(count_percentage)
    
    return missing_var, missing_count

# %%
check_missing_values(clean_df)

# %%
Russia_df = clean_df.loc[(clean_df["suicide_country"] == "Russia")]
Japan_df = clean_df.loc[(clean_df["suicide_country"] == "Japan")]

# %%
# Iteration 1

X = clean_df[
       
       'gdp_per_capita ($)'
]
# y = df["suicide_year"].values.reshape(-1, 1)
y = clean_df["suicides/100k pop"]

plt.scatter(X, y)

# %%
# Iteration 2
X = clean_df[["gdp_per_capita ($)", "Life Ladder"]]

y = clean_df["suicides/100k pop"].values.reshape(-1, 1)

print(X.shape, y.shape)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION

# %%
#not a great score - .051
model.score(X_test, y_test)

# %%
# Iteration 3
X = clean_df[['gdp_per_capita ($)',
       'Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption', 'Positive affect', 'Negative affect',
    'Confidence in national government', 'Democratic Quality',  'Delivery Quality'
]]

y = clean_df["suicides/100k pop"].values.reshape(-1, 1)

print(X.shape, y.shape)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION

# %%
#not a great score - .051
model.score(X_test, y_test)

# %%
# Iteration 3b
X = clean_df[['Log GDP per capita', 'Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

y = clean_df["suicides/100k pop"].values.reshape(-1, 1)

print(X.shape, y.shape)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION

# %%
#not a great score - .079
model.score(X_test, y_test)
