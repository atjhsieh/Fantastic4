# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import csv
from pprint import pprint

# %%
csv_file = "Merged.csv"
testing = pd.read_csv(csv_file)

# %%
testing.head()
# Out:
#   suicide_country  suicide_year     sex          age  suicides_no  population  \
# 0         Albania          2007    male    75+ years            8       42366
# 1         Albania          2007    male  35-54 years           29      378626
# 2         Albania          2007    male  55-74 years           14      224160
# 3         Albania          2007  female    75+ years            3       57404
# 4         Albania          2007    male  25-34 years            9      172494
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)  \
# 0              18.88  Albania2007           NaN      1.070101e+10
# 1               7.66  Albania2007           NaN      1.070101e+10
# 2               6.25  Albania2007           NaN      1.070101e+10
# 3               5.23  Albania2007           NaN      1.070101e+10
# 4               5.22  Albania2007           NaN      1.070101e+10
#
#         ...         Positive affect Negative affect  \
# ...

# %%
testing.describe()
# Out:
#        suicide_year   suicides_no    population  suicides/100k pop  \
# count   7172.000000   7172.000000  7.172000e+03        7172.000000
# mean    2010.697713    247.501813  2.331594e+06          11.589293
# std        2.936236    780.038646  4.510854e+06          15.646938
# min     2005.000000      0.000000  1.681000e+03           0.000000
# 25%     2008.000000      8.000000  2.647782e+05           1.600000
# 50%     2011.000000     42.000000  6.162005e+05           6.020000
# 75%     2013.000000    159.250000  2.362399e+06          14.942500
# max     2016.000000  11767.000000  4.380521e+07         187.060000
#
#        HDI for year  gdp_for_year ($)  gdp_per_capita ($)  \
# count   4068.000000      7.172000e+03         7172.000000
# mean       0.811493      7.918047e+11        25882.067485
# std        0.084566      2.170887e+12        23894.786583
# min        0.611000      1.290573e+09          610.000000
# 25%        0.751000      3.933277e+10         6734.000000
# ...
